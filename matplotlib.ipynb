# %%
! pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = np.arange(1, 25)
y = np.cos(2*np.pi*x)*np.exp(-x)

# %%
# Line Plot
plt.figure(figsize=(10,5))
plt.plot(x, y, color="darkorange", linewidth=2, marker='^')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("x vs cos(x)")
# plt.yticks([-1, 0, 1])
# plt.xticks([0,2,4])
plt.grid(True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="833.3333333333334">

# %%
# Line Plot
plt.figure(figsize=(10,5))
plt.plot(x, np.cos(x), color="darkorange", linewidth=2, marker='^', label="cosX")
plt.plot(x, np.sin(x), color="lightblue", linewidth=2, marker='^', label="sinX")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("x vs cos(x)")
plt.legend()
plt.grid(True)
plt.xlim([5,20])
plt.ylim([-0.75,0.75])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Bar 
age = [10,12,14,16,18,20]
students = [30,50,77,22,33,89]
plt.bar(age, students)
plt.title("Age Distribution")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Bar 
lang = ['Python', 'Java', 'C++']
demands = [150,50,77]
plt.barh(lang, demands)
plt.title("Age Distribution")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Histogram
plt.hist(age, bins=5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Scatter
y = np.random.random(24)
plt.scatter(x, y, color="purple", marker="*")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Pie
sports = ["Cricket", "Football", "Poetry", "VolleyBall"]
participation = [84, 74, 23, 50]
plt.pie(participation, labels=sports, explode=(0,0,0,0.1), shadow=(0,0,0,0.5),autopct='%1.3f%%')
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x1d2b6082400>,
# ...
#  [Text(0.4569564802357173, 1.000595210447554, 'Cricket'),
#   Text(-1.0877138949597427, -0.1639465849339529, 'Football'),
#   Text(-0.11200517161019662, -1.094282797787012, 'Poetry'),
#   Text(0.9330885378759979, -0.7545500516761182, 'VolleyBall')],
#  [Text(0.24924898921948213, 0.5457792056986657, '36.364%'),
#   Text(-0.5932984881598596, -0.08942540996397429, '32.035%'),
#   Text(-0.061093729969198145, -0.5968815260656428, '9.957%'),
#   Text(0.544301647094332, -0.44015419681106893, '21.645%')])

# %%
x = np.arange(1,101)
y = np.random.random(100)
z = np.random.random(100)

# %%
axes = plt.axes(projection="3d")
axes.scatter3D(x, y, z)
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes.set_zlabel("Z")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
